# %%
import pandas as pd

# %%
def load_and_process_data(file_path):
    data = pd.read_csv(file_path)
    print("First few rows of the dataset:")
    print(data.head())  
    return data

# %%
df_books = load_and_process_data('books.csv')

# %%
df_reviews = load_and_process_data('reviews.csv')

# %%
df_books.columns

# %%
df_reviews.columns

# %%
original_id = 'STU041'
my_hash = '34bc6d75'

# %%
is_my_book = df_reviews['text'].str.contains(my_hash, case=False, na=False)

# %%
my_book_info = df_reviews[is_my_book]

# %%
my_book_info.head()

# %%
filtered = df_books[(df_books['parent_asin']=='0008193754')]
print(filtered['title'])

# %%
book_title = filtered['title'].values[0]

# %%
book_title_hash = '2226d68638b2f6af6538f88abb31b0924993a7d2a9c8ce6436c7660f5a7b1fb2' # Flag 2
